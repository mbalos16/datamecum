# %% [markdown]
# <img src="datamecum_logo.png" align="right" style="float" width="400">
# <font color="#CA3532"><h1 align="left">Programa técnico intensivo en data science. Datamecum.</h1></font>
# <font color="#6E6E6E"><h2 align="left">Módulo Introducción a Python.</h2></font>
# <font color="#6E6E6E"><h2 align="left">Tarea 4</h2></font>
#
# #### Marcelino Martínez Sober, Juan Gómez-Sanchis
# ##### Alumna: Maria Balos

# %% [markdown]
# TO DO: *Crea un Notebook de Jupiter denominado Tarea4bis2.ipynb para completar los ejercicios propuestos en esta tarea.
#
# Define 3 variables a=7, b=8.5 y c=‘MasterDatos’. De qué tipo de datos son los objetos a los que hacen referencia las variables?. Utiliza la función adecuada para justificar la veracidad de tu respuesta.
#
# Cuales son los atributos y métodos de los objetos a los que hacen referencia a, b y c.?
# Añade comentarios a cada uno de los ejercicios.*

# %% [markdown]
# ---

# %% [markdown]
# Defining the variables a, b, and c

# %%
a = 7
b = 8.5
c = "MasterDatos"

# %% [markdown]
# Showing the type of each object

# %%
type_a = type(a)
print(type_a)

type_b = type(b)
print(type_b)

type_c = type(c)
print(type_c)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# Showing the methods and atributes of each type of object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:9a5596f6-4566-4867-9ff8-ee1df7be3a90.png)

# %% [markdown]
# ![image.png](attachment:f8e0a95d-ab00-4998-9c9b-6bd8b830760a.png)
